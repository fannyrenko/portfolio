# %% [markdown]
# ## Exercise 3 - Data sources
# - All files used in this exercise can be found under the Exercises/data_files directory

# %% [markdown]
# 1 Use gamedata.json for this task. This file contains information of games sold through Steam. Parse out the following information from the data:
# - TOP 3 highest metacritic score. Present results using the following format: *Title* has metacritic score of *Score* (for example)
# - Games with price discount being 90 % or more. Present results using the following format: *Title* | Discount: *Savings* (for example Metal Gear Solid V: Ground Zeroes | Discount: 90.090090)
# - Games having metacritic score higher than steam score. Present results using the following format: *Title* has metacritic score of *MetacriticScore* and steam score of *SteamRatingPercent*

# %%
import json

with open('data_files/gamedata.json') as gamedata:
  games = json.load(gamedata)

games_dict = {}

for game in games:
  games_dict[game["title"]] = game["metacriticScore"]

game_lst = sorted(games_dict.items(),key=lambda item: item[1])[-3:]

for game in game_lst:
  print("%s has metacirit score of %s" % (game[0],game[1]))
# Out:
# Bayonetta has metacirit score of 90
# Metal Gear Solid V: The Phantom Pain has metacirit score of 91
# Star Wars: Knights of the Old Republic has metacirit score of 93

# %% [markdown]
# 2 Use earthquakes.csv for this task. This file contains information about earthquakes recorded between 1965 and 2016. Earthquake magnitude value describes how strong the earthquake is. Magnitude information can be categorized like presented in the table below (*Source: http://www.geo.mtu.edu/UPSeis/magnitude.html*).
#
# | Magnitude      | Class | Effects |
# |----------------|-------|---------|
# | 2.4 or less    | Minor | Usually not felt, but can be recorded by seismograph. |
# | 2.5 to 5.4     | Light | Often felt, but only causes minor damage. |
# | 5.5 to 6.0     | Moderate | Slight damage to buildings and other structures. |
# | 6.1 to 6.9     | Strong | May cause a lot of damage in very populated areas. |
# | 7.0 to 7.9     | Major | Major earthquake. Serious damage. |
# | 8.0 or greater | Great | Great earthquake. Can totally destroy communities near the epicenter. |
#
# Count how many earthquakes have occurred in each class.
#
# <b style="color:red;">Notice:</b> The first value has been modified to be 2.4 or less compared to the original source (has been 2.5 or less).

# %%
import pandas as pd
earthquakes = pd.read_csv('data_files/earthquakes.csv',delimiter=",")
magnitude = earthquakes['Magnitude']
minor = 0
light = 0
moderate = 0
strong = 0
major = 0
great = 0

for value in magnitude:
    if value <= 2.4:
      minor += 1
    elif value >= 2.5 and value <= 5.4:
      light += 1
    elif value >= 5.5 and value <= 6.0:
      moderate += 1
    elif value >= 6.1 and value <= 6.9:
      strong += 1
    elif value >= 7.0 and value <= 7.9:
      major += 1
    elif value >= 8.0:
      great += 1
  
print(f"Minor: {minor} \nLight: {light}\nModerate: {moderate}\nStrong:{strong}\nMajor: {major}\nGreat: {great}")
# Out:
# Minor: 0
# Light: 0
# Moderate: 17638
# Strong:5035
# Major: 698
# Great: 40

# %% [markdown]
# 3 Use netflix_titles.xml for this task. This file contains information about Netflix movies and TV shows. **Important:** Movies have duration presented in minutes while TV shows have duration presented in amount of seasons! Parse out the following information from the data:
# - Movies released in 2017
# - TV show and movie amount (present both counts in separate lines)
# - Movies with a length between 15 and 20 minutes (values 15 and 20 included)

# %%
import xml.etree.ElementTree as e

tree = e.parse("data_files/netflix_titles.xml")
root = tree.getroot()

movie_collection = []
movies_2017 = []
movie_count = 0
show_count = 0
short_movies = []

for i in root:
    movie_obj = {}
    for j in i:
        movie_obj[j.tag] = j.text
    movie_collection.append(movie_obj)

for i in movie_collection:
    if ('2017' in i["release_year"] and 'Movie' in i['type']):
       movies_2017.append(i["title"])
    if ('Movie' in i['type']):
        movie_count += 1
    if ('TV Show' in i['type']):
        show_count += 1  
    if ('15 min' in i['duration']) and ('Tv Show' not in i['type']) and ('156' not in i['duration']) and ('150' not in i['duration']) and ('115' not in i['duration']) and ('154' not in i['duration'])   and ('153' not in i['duration']) and ('158' not in i['duration'])  and ('151' not in i['duration']) and ('157' not in i['duration']) and ('159' not in i['duration'])and ('155' not in i['duration']) and ('152' not in i['duration']) and ('15 Seasons' not in i['duration']):
        short_movie = i['title'], i['duration']
        short_movies.append(short_movie)
    if ('16 min' in i['duration']) and ('Tv Show' not in i['type']) and ('116' not in i['duration']) and ('168' not in i['duration']) and ('164' not in i['duration']) and ('162' not in i['duration'])   and ('153' not in i['duration']) and ('158' not in i['duration'])  and ('151' not in i['duration']) and ('157' not in i['duration']) and ('159' not in i['duration'])and ('155' not in i['duration']) and ('152' not in i['duration']) and ('15 Seasons' not in i['duration']):
        short_movie = i['title'], i['duration']
        short_movies.append(short_movie)
    if ('17 min' in i['duration']) and ('Tv Show' not in i['type']) and ('117' not in i['duration']):
        short_movie = i['title'], i['duration']
        short_movies.append(short_movie)
    if ('18 min' in i['duration']) and ('Tv Show' not in i['type']) and ('118' not in i['duration']):
        short_movie = i['title'], i['duration']
        short_movies.append(short_movie)
    if ('19 min' in i['duration']) and ('Tv Show' not in i['type']) and ('119' not in i['duration']):
        short_movie = i['title'], i['duration']
        short_movies.append(short_movie)
    if ('20 min' in i['duration']) and ('Tv Show' not in i['type']) and ('120' not in i['duration']) and ('200' not in i['duration']) and ('204' not in i['duration']) and ('209' not in i['duration'])   and ('203' not in i['duration']) and ('201' not in i['duration'])  and ('205' not in i['duration']) and ('208' not in i['duration']):
        short_movie = i['title'], i['duration']
        short_movies.append(short_movie)

print("Movies with duration 15-20 min:",*short_movies, sep="\n")    
print ("Movies made in 2017:",*movies_2017, sep="\n")
print("Amount of Movies: ",movie_count)
print("Amount of TV Shows: ",show_count)
# Out:
# Movies with duration 15-20 min:
# ('A Love Song for Latasha', '20 min')
# ('ANIMA', '15 min')
# ('John Was Trying to Contact Aliens', '17 min')
# ('Little Miss Sumo', '20 min')
# ('Michael Lost and Found', '19 min')
# ('Pocoyo & Cars', '19 min')
# ('Sitara: Let Girls Dream', '16 min')
# ('The Battle of Midway', '18 min')
# ('The Claudia Kishi Club', '17 min')
# ('WHAT DID JACK DO?', '17 min')
# ('Ya no estoy aquí: Una conversación entre Guillermo del Toro y Alfonso Cuarón', '15 min')
# Movies made in 2017:
# 1922
# '89
# ​Maj Rati ​​Keteki
# ​Mayurakshi
# #realityhigh
# Ég man þig
# 1 Mile to You
# 10 Days in Sun City
# 12 ROUND GUN
# 13TH: A Conversation with Oprah Winfrey & Ava DuVernay
# 24 Hours to Live
# 27: Gone Too Soon
# 42 Grams
# 48 Christmas Wishes
# 5 Cowok Jagoan
# 6 Days
# 68 Kill
# A Bad Moms Christmas
# A Christmas Prince
# A Ghost Story
# A Gray State
# A new Capitalism
# A Sort of Family
# A StoryBots Christmas
# A Very Country Christmas
# A Week in Watts
# ...

# %% [markdown]
# 4 Use the following Rest API for this task: https://tie.digitraffic.fi/api/v1/data/weather-data. Calculate the average for air temperature (ILMA) and humidity (ILMAN_KOSTEUS) values using two decimals.

# %%
import requests

url = "https://tie.digitraffic.fi/api/v1/data/weather-data"
req = requests.get(url=url)
weather_data = req.json()['weatherStations']
air_temp = []
hum = []
for item in weather_data:
    for subitem in item['sensorValues']:
        if subitem['name'] == "ILMA":
            air_temp.append(subitem['sensorValue'])
        if subitem['name'] == "ILMAN_KOSTEUS":
            hum.append(subitem['sensorValue'])
            
def Average(lst):
    return sum(lst) / len(lst)

air_temp_average = Average(air_temp)
hum_average = Average(hum)

print("Air tempature average:", round(air_temp_average,2))
print("Humidity average:", round(hum_average,2))
# Out:
# Air tempature average: 2.29
# Humidity average: 67.28
